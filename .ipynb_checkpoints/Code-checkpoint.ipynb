# %%
import networkx as nx
import matplotlib.pyplot as plt
import random
import numpy as np

# %% [markdown]
# # Part 1

# %% [markdown]
# ### a)

# %%
def plot_attack(G, network_name, step):
    
    if not nx.is_connected(G):
        #print("graph not connected! From now on the largest component will be considered as the graph")  
        G =  G.subgraph(sorted(nx.connected_components(G), key=len, reverse=True)[0]).copy()
    
    print("Number of nodes of the giant component: ", nx.number_of_nodes(G))

    G_random_attack = G.copy()
    G_betweenness_attack = G.copy()
    G_pagerank_attack = G.copy()
    G_high_dregree_attack = G.copy()
    
    starting_diameter = nx.diameter(G)
    tot_nodes = nx.number_of_nodes(G)
    f_list = np.arange(0, (1 + step/tot_nodes), step/tot_nodes)

    # BETWEENNESS    
    diameter_list_betweenness = np.zeros(len(f_list))
    giant_component_size_list_betweeness = np.zeros(len(f_list))
    giant_component_size_list_betweeness[0] = len(G)
 
    i = 1
    print("\n\nBetwenness Attack: \n\n")
    while nx.number_of_nodes(G_betweenness_attack) >= step+1 and i < len(f_list): 
        #find node with highest betweenness
        
        betweenness_dict = nx.betweenness_centrality(G_betweenness_attack)
        sorted_key = sorted(betweenness_dict, key=betweenness_dict.get, reverse=True)

        ##Remove nodes with highest betweenness
        G_betweenness_attack.remove_nodes_from(sorted_key[:step])

        if not nx.is_connected(G_betweenness_attack) :
            #print("graph not connected! From now on the largest component will be considered as the graph")  
            G_betweenness_attack =  G_betweenness_attack.subgraph( sorted(nx.connected_components(G_betweenness_attack), key=len, reverse=True)[0]).copy()
        
       
        print("Step: ", i)
        giant_component_size_list_betweeness[i] = nx.number_of_nodes(G_betweenness_attack)
        diameter_list_betweenness[i] = nx.diameter(G_betweenness_attack)
        print("Remaining Nodes: {}".format(nx.number_of_nodes(G_betweenness_attack)))
        
        i += 1
       

    
    # HIGH DEGREE 
    diameter_list_deg = np.zeros(len(f_list))
    giant_component_size_list_deg = np.zeros(len(f_list))
    giant_component_size_list_deg[0] = len(G)
    i =1
    print("\n\nHigh Degree Attack: \n\n")
    while nx.number_of_nodes(G_high_dregree_attack) >= step+1 and i < len(f_list): 
        # degree of the nodes
        degree_dict = dict(G_high_dregree_attack.degree)
        sorted_key = sorted(degree_dict, key=degree_dict.get, reverse=True)
       
        #remove node with highest degree
        G_high_dregree_attack.remove_nodes_from(sorted_key[:step])
   
        if not nx.is_connected(G_high_dregree_attack):
            #print("graph not connected! From now on the largest component will be considered as the graph")  
            G_high_dregree_attack =  G_high_dregree_attack.subgraph(sorted(nx.connected_components(G_high_dregree_attack), key=len, reverse=True)[0]).copy()
            
      
        print("Step: ", i)
        giant_component_size_list_deg[i] = nx.number_of_nodes(G_high_dregree_attack)
        diameter_list_deg[i] = nx.diameter(G_high_dregree_attack)
        print("Remaining Nodes: {}".format(nx.number_of_nodes(G_high_dregree_attack)))

        i += 1
        

    # RANDOM NODE
    diameter_list_random = np.zeros(len(f_list))
    giant_component_size_list_random = np.zeros(len(f_list))
    giant_component_size_list_random[0] = len(G)
    i = 1

    print("\n\nRandom Attack: \n\n")
    while nx.number_of_nodes(G_random_attack) >= step+1 and i < len(f_list): 

        #pick random node
        nodes_list = list(G_random_attack.nodes)
        random_nodes = random.sample(nodes_list, step)
        #remove random node
        
        G_random_attack.remove_nodes_from(random_nodes)

        if not nx.is_connected(G_random_attack):
            #print("graph not connected! From now on the largest component will be considered as the graph")  
            G_random_attack =  G_random_attack.subgraph(sorted(nx.connected_components(G_random_attack), key=len, reverse=True)[0]).copy()
            
        print("Step: ", i)
        giant_component_size_list_random[i] = nx.number_of_nodes(G_random_attack)
        diameter_list_random[i] = nx.diameter(G_random_attack)
        print("Remaining Nodes: {}".format(nx.number_of_nodes(G_random_attack)))

        i += 1
        
    
    #PAGERANK
    
    diameter_list_pagerank = np.zeros(len(f_list))
    giant_component_size_list_pagerank = np.zeros(len(f_list))
    giant_component_size_list_pagerank[0] = len(G)

    i = 1
    print("\n\nPagerank Attack: \n\n")
    while nx.number_of_nodes(G_pagerank_attack) >= step+1 and i < len(f_list): 
        # computing page rank
        pageRank_dict = nx.pagerank(G_pagerank_attack)

        #pick the step nodes with maximum pagerank
        sorted_key = sorted(pageRank_dict, key=pageRank_dict.get, reverse=True)

        #remove the node with highest pagerank
        G_pagerank_attack.remove_nodes_from( sorted_key[:step] )

        if not nx.is_connected(G_pagerank_attack):
            #print("graph not connected! From now on the largest component will be considered as the graph")  
            G_pagerank_attack =  G_pagerank_attack.subgraph(sorted(nx.connected_components(G_pagerank_attack), key=len, reverse=True)[0]).copy()
            
        print("Step: ", i)       
        giant_component_size_list_pagerank[i] = nx.number_of_nodes(G_pagerank_attack)
        diameter_list_pagerank[i] = nx.diameter(G_pagerank_attack)
        print("Remaining Nodes: {}".format(nx.number_of_nodes(G_pagerank_attack)))

        i += 1
       

    

    plt.figure( figsize=(15,10))

    plt.plot(f_list, giant_component_size_list_betweeness/tot_nodes, label="Betweenness Attack", lw=3)
    plt.plot(f_list, giant_component_size_list_random/tot_nodes, label="Random Node Attack", lw=3)
    plt.plot(f_list, giant_component_size_list_deg/tot_nodes, label="High Degree Node Attack", lw=3)
    plt.plot(f_list, giant_component_size_list_pagerank/tot_nodes, label="Pagerank Attack", lw=3)

    plt.xlabel("f", fontsize=15)
    plt.ylabel("Giant Component Size ( fraction ) ", fontsize=15)
    plt.title(network_name + " Giant Component Size", fontsize=20)
    plt.legend(fontsize=15)
    plt.savefig("images/"+network_name+"_giant_component_size.png")


    plt.figure( figsize=(15,10))

    plt.plot(f_list, diameter_list_betweenness, label="Betweenness Attack", lw=3)
    plt.plot(f_list, diameter_list_random, label="Random Node Attack", lw=3)
    plt.plot(f_list, diameter_list_deg, label="High Degree Node Attack", lw=3)
    plt.plot(f_list, diameter_list_pagerank, label="Pagerank Attack", lw=3)

    plt.xlabel("f", fontsize=15)
    plt.ylabel("Diameter ", fontsize=15)
    plt.title(network_name+" Diameter", fontsize=20)
    plt.legend(fontsize=15)
    plt.savefig("images/"+network_name+"_diameter.png")

# %% [markdown]
# ## Karate Club Graph

# %%
G = nx.karate_club_graph()

# number of nodes
N = nx.number_of_nodes(G)
print("Number of nodes: ", N)

# number of links
print("Number of edges: ", nx.number_of_edges(G))

# average degree
print("Average degree: ", sum([d for n, d in G.degree()])/nx.number_of_nodes(G))

# Density
print("Density: ", nx.density(G))

# Global clustering
print("Global clustering: ", nx.transitivity(G))

# Average clustering
print("Average clustering: ", nx.average_clustering(G))
# Out:
# Number of nodes:  34
# Number of edges:  78
# Average degree:  4.588235294117647
# Density:  0.13903743315508021
# Global clustering:  0.2556818181818182
# Average clustering:  0.5706384782076823

# %%
plt.figure( figsize=(13, 10))
nx.draw(G)
plt.savefig("images/graph1.png")

# %%
plot_attack(G, "Karate Club", 1)
# Out:
# Number of nodes of the giant component:  34
#
#
# Betwenness Attack:
#
#
# Step:  1
# Remaining Nodes: 27
# Step:  2
# Remaining Nodes: 26
# Step:  3
# Remaining Nodes: 20
# Step:  4
# Remaining Nodes: 10
# Step:  5
# Remaining Nodes: 4
# Step:  6
# Remaining Nodes: 1
#
#
# High Degree Attack:
#
#
# Step:  1
# Remaining Nodes: 33
# Step:  2
# Remaining Nodes: 26
# Step:  3
# Remaining Nodes: 20
# Step:  4
# Remaining Nodes: 16
# Step:  5
# Remaining Nodes: 8
# Step:  6
# Remaining Nodes: 5
# Step:  7
# Remaining Nodes: 3
# Step:  8
# Remaining Nodes: 1
#
#
# Random Attack:
#
#
# Step:  1
# Remaining Nodes: 33
# Step:  2
# Remaining Nodes: 32
# Step:  3
# Remaining Nodes: 31
# Step:  4
# Remaining Nodes: 30
# Step:  5
# Remaining Nodes: 29
# Step:  6
# Remaining Nodes: 28
# Step:  7
# Remaining Nodes: 27
# Step:  8
# Remaining Nodes: 26
# Step:  9
# Remaining Nodes: 25
# Step:  10
# Remaining Nodes: 24
# Step:  11
# Remaining Nodes: 23
# Step:  12
# Remaining Nodes: 22
# Step:  13
# Remaining Nodes: 21
# Step:  14
# Remaining Nodes: 20
# Step:  15
# Remaining Nodes: 19
# Step:  16
# Remaining Nodes: 15
# Step:  17
# Remaining Nodes: 9
# Step:  18
# Remaining Nodes: 8
# Step:  19
# Remaining Nodes: 7
# Step:  20
# Remaining Nodes: 6
# Step:  21
# Remaining Nodes: 5
# Step:  22
# Remaining Nodes: 2
# Step:  23
# Remaining Nodes: 1
#
#
# Pagerank Attack:
#
#
# Step:  1
# Remaining Nodes: 33
# Step:  2
# Remaining Nodes: 26
# Step:  3
# Remaining Nodes: 20
# Step:  4
# Remaining Nodes: 16
# Step:  5
# Remaining Nodes: 8
# Step:  6
# Remaining Nodes: 5
# Step:  7
# Remaining Nodes: 3
# Step:  8
# Remaining Nodes: 1

# %% [markdown]
# ### Random Graph - Erdos Renyi Graph

# %%
G = nx.erdos_renyi_graph(200, 0.1, seed=123, directed=False)

# number of nodes
N = nx.number_of_nodes(G)
print("Number of nodes: ", N)

# number of links
print("Number of edges: ", nx.number_of_edges(G))

# average degree
print("Average degree: ", sum([d for n, d in G.degree()])/nx.number_of_nodes(G))

# Density
print("Density: ", nx.density(G))

# Global clustering
print("Global clustering: ", nx.transitivity(G))

# Average clustering
print("Average clustering: ", nx.average_clustering(G))
# Out:
# Number of nodes:  200
# Number of edges:  2017
# Average degree:  20.17
# Density:  0.10135678391959799
# Global clustering:  0.10058265850286391
# Average clustering:  0.09894891209339168

# %%
plt.figure( figsize=(13, 10))
nx.draw(G)
plt.savefig("images/graph2.png")

# %% [markdown]
# # Part 2

# %%
def load_dataset(sample = False, K = None):
    
    # if sample == True then only K randomly selected nodes are loaded
    
    # create graph
    G = nx.Graph()
    node_list = []

    with open("dataset/facebook_combined.edges") as edges:
        
        
        for row in edges:
            if len(row.split(" ")) == 1:
                continue
        
            source, target = row.split(" ")[:2]
            source = int(source)
            target = int(target)
            
            # add all the nodes and the edges
            if not sample:
                # add nodes if not in yet
                if source not in G:
                    G.add_node(source)
        
                if target not in G:
                    G.add_node(target)
        
                # add edge
                G.add_edge(source, target)
                
            else:
                # prepare the list to randomply sample
                
                if source not in node_list:
                    node_list.append(source)
                    
                if target not in node_list:
                    node_list.append(target)
        
        if sample:
            node_list = random.sample(node_list , k = K)
                    
            # add all the selected node
            for node in node_list:
                    if node not in G:
                        G.add_node(node)
                            
            # add all the edges linking the selected nodes
            for row in edges:
                if len(row.split(" ")) == 1:
                    continue
        
                source, target = row.split(" ")[:2]
                source = int(source)
                target = int(target)
                
                if source in G and target in G:
                    # add edge
                    G.add_edge(source, target)
        return G

# %% [markdown]
# ## Facebook Circles Combined

# %%
# load graph with all nodes
G = load_dataset()
# number of nodes
N = nx.number_of_nodes(G)
print("Number of nodes: ", N)

# number of links
print("Number of edges: ", nx.number_of_edges(G))

# average degree
print("Average degree: ", sum([d for n, d in G.degree()])/nx.number_of_nodes(G))

# Density
print("Density: ", nx.density(G))

# Global clustering
print("Global clustering: ", nx.transitivity(G))

# Average clustering
print("Average clustering: ", nx.average_clustering(G))
# Out:
# Number of nodes:  4039
# Number of edges:  88234
# Average degree:  43.69101262688784
# Density:  0.010819963503439287
# Global clustering:  0.5191742775433075
# Average clustering:  0.6055467186200876

# %%
plot_attack(G, "Facebook Circles Combined",10)
# Out:
# 26
# Remaining Nodes: 363
# Step:  27
# Remaining Nodes: 351
# Step:  28
# Remaining Nodes: 300
# Step:  29
# Remaining Nodes: 283
# Step:  30
# Remaining Nodes: 272
# Step:  31
# Remaining Nodes: 253
# Step:  32
# Remaining Nodes: 239
# Step:  33
# Remaining Nodes: 228
# Step:  34
# Remaining Nodes: 218
# Step:  35
# Remaining Nodes: 206
# Step:  36
# Remaining Nodes: 193
# Step:  37
# Remaining Nodes: 183
# Step:  38
# Remaining Nodes: 173
# Step:  39
# Remaining Nodes: 163
# Step:  40
# Remaining Nodes: 153
# Step:  41
# Remaining Nodes: 142
# Step:  42
# Remaining Nodes: 132
# Step:  43
# Remaining Nodes: 122
# Step:  44
# Remaining Nodes: 111
# Step:  45
# Remaining Nodes: 95
# Step:  46
# Remaining Nodes: 77
# Step:  47
# Remaining Nodes: 63
# Step:  48
# Remaining Nodes: 27
# Step:  49
# Remaining Nodes: 12
# Step:  50
# Remaining Nodes: 1
#
#
# High Degree Attack:
#
#
# Step:  0
# Remaining Nodes: 3957
# Step:  1
# Remaining Nodes: 3944
# Step:  2
# Remaining Nodes: 3934
# Step:  3
# Remaining Nodes: 3924
# Step:  4
# Remaining Nodes: 3914
# Step:  5
# Remaining Nodes: 3904
# Step:  6
# Remaining Nodes: 3892
# Step:  7
# Remaining Nodes: 3881
# Step:  8
# Remaining Nodes: 3860
# Step:  9
# Remaining Nodes: 3850
# Step:  10
# Remaining Nodes: 3840
# Step:  11
# Remaining Nodes: 3830
# Step:  12
# Remaining Nodes: 3820
# Step:  13
# Remaining Nodes: 3810
# Step:  14
# Remaining Nodes: 3800
# Step:  15
# Remaining Nodes: 3790
# Step:  16
# Remaining Nodes: 3780
# Step:  17
# Remaining Nodes: 3770
# Step:  18
# Remaining Nodes: 3736
# Step:  19
# Remaining Nodes: 3726
# Step:  20
# Remaining Nodes: 3716
# Step:  21
# Remaining Nodes: 3706
# Step:  22
# Remaining Nodes: 3695
# Step:  23
# Remaining Nodes: 3685
# Step:  24
# Remaining Nodes: 3675
# Step:  25
# Remaining Nodes: 3665
# Step:  26
# Remaining Nodes: 3654
# Step:  27
# Remaining Nodes: 3582
# Step:  28
# Remaining Nodes: 3572
# Step:  29
# Remaining Nodes: 3561
# Step:  30
# Remaining Nodes: 3551
# Step:  31
# Remaining Nodes: 3541
# Step:  32
# Remaining Nodes: 3531
# Step:  33
# Remaining Nodes: 3521
# Step:  34
# Remaining Nodes: 3511
# Step:  35
# Remaining Nodes: 3499
# Step:  36
# Remaining Nodes: 3488
# Step:  37
# Remaining Nodes: 3478
# Step:  38
# Remaining Nodes: 3468
# Step:  39
# Remaining Nodes: 3267
# Step:  40
# Remaining Nodes: 3257
# Step:  41
# Remaining Nodes: 3247
# Step:  42
# Remaining Nodes: 3237
# Step:  43
# Remaining Nodes: 3226
# Step:  44
# Remaining Nodes: 3216
# Step:  45
# Remaining Nodes: 3206
# Step:  46
# Remaining Nodes: 3196
# Step:  47
# Remaining Nodes: 3186
# Step:  48
# Remaining Nodes: 3175
# Step:  49
# Remaining Nodes: 3165
# Step:  50
# Remaining Nodes: 3155
# Step:  51
# Remaining Nodes: 3145
# Step:  52
# Remaining Nodes: 3135
# Step:  53
# Remaining Nodes: 3125
# Step:  54
# Remaining Nodes: 3115
# Step:  55
# Remaining Nodes: 3104
# Step:  56
# Remaining Nodes: 3094
# Step:  57
# Remaining Nodes: 3084
# Step:  58
# Remaining Nodes: 3072
# Step:  59
# Remaining Nodes: 3062
# Step:  60
# Remaining Nodes: 2536
# Step:  61
# Remaining Nodes: 2525
# Step:  62
# Remaining Nodes: 2514
# Step:  63
# Remaining Nodes: 2504
# Step:  64
# Remaining Nodes: 2494
# Step:  65
# Remaining Nodes: 2484
# Step:  66
# Remaining Nodes: 2474
# Step:  67
# Remaining Nodes: 2464
# Step:  68
# Remaining Nodes: 2454
# Step:  69
# Remaining Nodes: 2443
# Step:  70
# Remaining Nodes: 1948
# Step:  71
# Remaining Nodes: 1937
# Step:  72
# Remaining Nodes: 1926
# Step:  73
# Remaining Nodes: 1915
# Step:  74
# Remaining Nodes: 1904
# Step:  75
# Remaining Nodes: 1894
# Step:  76
# Remaining Nodes: 1883
# Step:  77
# Remaining Nodes: 1873
# Step:  78
# Remaining Nodes: 1863
# Step:  79
# Remaining Nodes: 1853
# Step:  80
# Remaining Nodes: 1843
# Step:  81
# Remaining Nodes: 1833
# Step:  82
# Remaining Nodes: 1823
# Step:  83
# Remaining Nodes: 1812
# Step:  84
# Remaining Nodes: 1802
# Step:  85
# Remaining Nodes: 1790
# Step:  86
# Remaining Nodes: 1780
# Step:  87
# Remaining Nodes: 1769
# Step:  88
# Remaining Nodes: 1759
# Step:  89
# Remaining Nodes: 1749
# Step:  90
# Remaining Nodes: 1737
# Step:  91
# Remaining Nodes: 1725
# Step:  92
# Remaining Nodes: 1715
# Step:  93
# Remaining Nodes: 1705
# Step:  94
# Remaining Nodes: 1692
# Step:  95
# Remaining Nodes: 1682
# Step:  96
# Remaining Nodes: 1662
# Step:  97
# Remaining Nodes: 1652
# Step:  98
# Remaining Nodes: 1642
# Step:  99
# Remaining Nodes: 1631
# Step:  100
# Remaining Nodes: 1621
# Step:  101
# Remaining Nodes: 1600
# Step:  102
# Remaining Nodes: 1588
# Step:  103
# Remaining Nodes: 1574
# Step:  104
# Remaining Nodes: 1564
# Step:  105
# Remaining Nodes: 1474
# Step:  106
# Remaining Nodes: 1464
# Step:  107
# Remaining Nodes: 1453
# Step:  108
# Remaining Nodes: 1443
# Step:  109
# Remaining Nodes: 1433
# Step:  110
# Remaining Nodes: 1423
# Step:  111
# Remaining Nodes: 1413
# Step:  112
# Remaining Nodes: 1403
# Step:  113
# Remaining Nodes: 1391
# Step:  114
# Remaining Nodes: 1381
# Step:  115
# Remaining Nodes: 1371
# Step:  116
# Remaining Nodes: 1361
# Step:  117
# Remaining Nodes: 1346
# Step:  118
# Remaining Nodes: 1335
# Step:  119
# Remaining Nodes: 1322
# Step:  120
# Remaining Nodes: 1312
# Step:  121
# Remaining Nodes: 1301
# Step:  122
# Remaining Nodes: 1291
# Step:  123
# Remaining Nodes: 1280
# Step:  124
# Remaining Nodes: 1269
# Step:  125
# Remaining Nodes: 1259
# Step:  126
# Remaining Nodes: 1248
# Step:  127
# Remaining Nodes: 1227
# Step:  128
# Remaining Nodes: 1217
# Step:  129
# Remaining Nodes: 1205
# Step:  130
# Remaining Nodes: 1194
# Step:  131
# Remaining Nodes: 1165
# Step:  132
# Remaining Nodes: 1148
# Step:  133
# Remaining Nodes: 1136
# Step:  134
# Remaining Nodes: 1122
# Step:  135
# Remaining Nodes: 1015
# Step:  136
# Remaining Nodes: 989
# Step:  137
# Remaining Nodes: 845
# Step:  138
# Remaining Nodes: 828
# Step:  139
# Remaining Nodes: 813
# Step:  140
# Remaining Nodes: 791
# Step:  141
# Remaining Nodes: 770
# Step:  142
# Remaining Nodes: 754
# Step:  143
# Remaining Nodes: 530
# Step:  144
# Remaining Nodes: 469
# Step:  145
# Remaining Nodes: 456
# Step:  146
# Remaining Nodes: 416
# Step:  147
# Remaining Nodes: 405
# Step:  148
# Remaining Nodes: 378
# Step:  149
# Remaining Nodes: 300
# Step:  150
# Remaining Nodes: 224
# Step:  151
# Remaining Nodes: 96
# Step:  152
# Remaining Nodes: 18
# Step:  153
# Remaining Nodes: 2
#
#
# Random Attack:
#
#
# Step:  0
# Remaining Nodes: 4029
# Step:  1
# Remaining Nodes: 4019
# Step:  2
# Remaining Nodes: 4009
# Step:  3
# Remaining Nodes: 3999
# Step:  4
# Remaining Nodes: 3989
# Step:  5
# Remaining Nodes: 3979
# Step:  6
# Remaining Nodes: 3969
# Step:  7
# Remaining Nodes: 3959
# Step:  8
# Remaining Nodes: 3949
# Step:  9
# Remaining Nodes: 3939
# Step:  10
# Remaining Nodes: 3929
# Step:  11
# Remaining Nodes: 3919
# Step:  12
# Remaining Nodes: 3909
# Step:  13
# Remaining Nodes: 3899
# Step:  14
# Remaining Nodes: 3889
# Step:  15
# Remaining Nodes: 3879
# Step:  16
# Remaining Nodes: 3869
# Step:  17
# Remaining Nodes: 3859
# Step:  18
# Remaining Nodes: 3849
# Step:  19
# Remaining Nodes: 3839
# Step:  20
# Remaining Nodes: 3829
# Step:  21
# Remaining Nodes: 3819
# Step:  22
# Remaining Nodes: 3809
# Step:  23
# Remaining Nodes: 3799
# Step:  24
# Remaining Nodes: 3789
# Step:  25
# Remaining Nodes: 3779
# Step:  26
# Remaining Nodes: 3769
# Step:  27
# Remaining Nodes: 3759
# Step:  28
# Remaining Nodes: 3749
# Step:  29
# Remaining Nodes: 3739
# Step:  30
# Remaining Nodes: 3729
# Step:  31
# Remaining Nodes: 3719
# Step:  32
# Remaining Nodes: 3709
# Step:  33
# Remaining Nodes: 3699
# Step:  34
# Remaining Nodes: 3689
# Step:  35
# Remaining Nodes: 3679
# Step:  36
# Remaining Nodes: 3669
# Step:  37
# Remaining Nodes: 3659
# Step:  38
# Remaining Nodes: 3649
# Step:  39
# Remaining Nodes: 3639
# Step:  40
# Remaining Nodes: 3629
# Step:  41
# Remaining Nodes: 3619
# Step:  42
# Remaining Nodes: 3609
# Step:  43
# Remaining Nodes: 3599
# Step:  44
# Remaining Nodes: 3589
# Step:  45
# Remaining Nodes: 3579
# Step:  46
# Remaining Nodes: 3564
# Step:  47
# Remaining Nodes: 3554
# Step:  48
# Remaining Nodes: 3544
# Step:  49
# Remaining Nodes: 3534
# Step:  50
# Remaining Nodes: 3524
# Step:  51
# Remaining Nodes: 3514
# Step:  52
# Remaining Nodes: 3504
# Step:  53
# Remaining Nodes: 3494
# Step:  54
# Remaining Nodes: 3484
# Step:  55
# Remaining Nodes: 3467
# Step:  56
# Remaining Nodes: 3457
# Step:  57
# Remaining Nodes: 3447
# Step:  58
# Remaining Nodes: 3437
# Step:  59
# Remaining Nodes: 3427
# Step:  60
# Remaining Nodes: 3417
# Step:  61
# Remaining Nodes: 3407
# Step:  62
# Remaining Nodes: 3397
# Step:  63
# Remaining Nodes: 3387
# Step:  64
# Remaining Nodes: 3377
# Step:  65
# Remaining Nodes: 3367
# Step:  66
# Remaining Nodes: 3357
# Step:  67
# Remaining Nodes: 3347
# Step:  68
# Remaining Nodes: 3337
# Step:  69
# Remaining Nodes: 3327
# Step:  70
# Remaining Nodes: 3317
# Step:  71
# Remaining Nodes: 3307
# Step:  72
# Remaining Nodes: 3297
# Step:  73
# Remaining Nodes: 3287
# Step:  74
# Remaining Nodes: 3277
# Step:  75
# Remaining Nodes: 3267
# Step:  76
# Remaining Nodes: 3257
# Step:  77
# Remaining Nodes: 3247
# Step:  78
# Remaining Nodes: 3237
# Step:  79
# Remaining Nodes: 3227
# Step:  80
# Remaining Nodes: 3217
# Step:  81
# Remaining Nodes: 3207
# Step:  82
# Remaining Nodes: 3197
# Step:  83
# Remaining Nodes: 3187
# Step:  84
# Remaining Nodes: 3177
# Step:  85
# Remaining Nodes: 3167
# Step:  86
# Remaining Nodes: 3157
# Step:  87
# Remaining Nodes: 3147
# Step:  88
# Remaining Nodes: 3137
# Step:  89
# Remaining Nodes: 3127
# Step:  90
# Remaining Nodes: 3117
# Step:  91
# Remaining Nodes: 3107
# Step:  92
# Remaining Nodes: 3097
# Step:  93
# Remaining Nodes: 3087
# Step:  94
# Remaining Nodes: 3077
# Step:  95
# Remaining Nodes: 3067
# Step:  96
# Remaining Nodes: 3057
# Step:  97
# Remaining Nodes: 3047
# Step:  98
# Remaining Nodes: 3037
# Step:  99
# Remaining Nodes: 3027
# Step:  100
# Remaining Nodes: 3017
# Step:  101
# Remaining Nodes: 3007
# Step:  102
# Remaining Nodes: 2997
# Step:  103
# Remaining Nodes: 2987
# Step:  104
# Remaining Nodes: 2977
# Step:  105
# Remaining Nodes: 2967
# Step:  106
# Remaining Nodes: 2957
# Step:  107
# Remaining Nodes: 2947
# Step:  108
# Remaining Nodes: 2937
# Step:  109
# Remaining Nodes: 2927
# Step:  110
# Remaining Nodes: 2917
# Step:  111
# Remaining Nodes: 2907
# Step:  112
# Remaining Nodes: 2897
# Step:  113
# Remaining Nodes: 2887
# Step:  114
# Remaining Nodes: 2877
# Step:  115
# Remaining Nodes: 2867
# Step:  116
# Remaining Nodes: 2850
# Step:  117
# Remaining Nodes: 2824
# Step:  118
# Remaining Nodes: 2814
# Step:  119
# Remaining Nodes: 2804
# Step:  120
# Remaining Nodes: 2794
# Step:  121
# Remaining Nodes: 2784
# Step:  122
# Remaining Nodes: 2774
# Step:  123
# Remaining Nodes: 2764
# Step:  124
# Remaining Nodes: 2754
# Step:  125
# Remaining Nodes: 2744
# Step:  126
# Remaining Nodes: 2734
# Step:  127
# Remaining Nodes: 2724
# Step:  128
# Remaining Nodes: 2714
# Step:  129
# Remaining Nodes: 2704
# Step:  130
# Remaining Nodes: 2694
# Step:  131
# Remaining Nodes: 2684
# Step:  132
# Remaining Nodes: 2674
# Step:  133
# Remaining Nodes: 2664
# Step:  134
# Remaining Nodes: 2654
# Step:  135
# Remaining Nodes: 2644
# Step:  136
# Remaining Nodes: 2634
# Step:  137
# Remaining Nodes: 2624
# Step:  138
# Remaining Nodes: 2614
# Step:  139
# Remaining Nodes: 2604
# Step:  140
# Remaining Nodes: 2594
# Step:  141
# Remaining Nodes: 2584
# Step:  142
# Remaining Nodes: 2574
# Step:  143
# Remaining Nodes: 2564
# Step:  144
# Remaining Nodes: 2554
# Step:  145
# Remaining Nodes: 2544
# Step:  146
# Remaining Nodes: 2534
# Step:  147
# Remaining Nodes: 2509
# Step:  148
# Remaining Nodes: 2499
# Step:  149
# Remaining Nodes: 2489
# Step:  150
# Remaining Nodes: 2479
# Step:  151
# Remaining Nodes: 2469
# Step:  152
# Remaining Nodes: 2459
# Step:  153
# Remaining Nodes: 2449
# Step:  154
# Remaining Nodes: 2439
# Step:  155
# Remaining Nodes: 2429
# Step:  156
# Remaining Nodes: 2419
# Step:  157
# Remaining Nodes: 2381
# Step:  158
# Remaining Nodes: 2371
# Step:  159
# Remaining Nodes: 2361
# Step:  160
# Remaining Nodes: 2351
# Step:  161
# Remaining Nodes: 2341
# Step:  162
# Remaining Nodes: 2331
# Step:  163
# Remaining Nodes: 2321
# Step:  164
# Remaining Nodes: 2310
# Step:  165
# Remaining Nodes: 2300
# Step:  166
# Remaining Nodes: 2290
# Step:  167
# Remaining Nodes: 2280
# Step:  168
# Remaining Nodes: 2270
# Step:  169
# Remaining Nodes: 2260
# Step:  170
# Remaining Nodes: 2250
# Step:  171
# Remaining Nodes: 2240
# Step:  172
# Remaining Nodes: 2230
# Step:  173
# Remaining Nodes: 2220
# Step:  174
# Remaining Nodes: 2210
# Step:  175
# Remaining Nodes: 2200
# Step:  176
# Remaining Nodes: 2190
# Step:  177
# Remaining Nodes: 2180
# Step:  178
# Remaining Nodes: 2170
# Step:  179
# Remaining Nodes: 2159
# Step:  180
# Remaining Nodes: 2149
# Step:  181
# Remaining Nodes: 2138
# Step:  182
# Remaining Nodes: 2128
# Step:  183
# Remaining Nodes: 2118
# Step:  184
# Remaining Nodes: 2108
# Step:  185
# Remaining Nodes: 2098
# Step:  186
# Remaining Nodes: 2088
# Step:  187
# Remaining Nodes: 2078
# Step:  188
# Remaining Nodes: 2067
# Step:  189
# Remaining Nodes: 2024
# Step:  190
# Remaining Nodes: 2014
# Step:  191
# Remaining Nodes: 2004
# Step:  192
# Remaining Nodes: 1994
# Step:  193
# Remaining Nodes: 1984
# Step:  194
# Remaining Nodes: 1972
# Step:  195
# Remaining Nodes: 1961
# Step:  196
# Remaining Nodes: 1951
# Step:  197
# Remaining Nodes: 1941
# Step:  198
# Remaining Nodes: 1931
# Step:  199
# Remaining Nodes: 1919
# Step:  200
# Remaining Nodes: 1909
# Step:  201
# Remaining Nodes: 1899
# Step:  202
# Remaining Nodes: 1889
# Step:  203
# Remaining Nodes: 1879
# Step:  204
# Remaining Nodes: 1857
# Step:  205
# Remaining Nodes: 1846
# Step:  206
# Remaining Nodes: 1836
# Step:  207
# Remaining Nodes: 1826
# Step:  208
# Remaining Nodes: 1816
# Step:  209
# Remaining Nodes: 1806
# Step:  210
# Remaining Nodes: 1796
# Step:  211
# Remaining Nodes: 1786
# Step:  212
# Remaining Nodes: 1775
# Step:  213
# Remaining Nodes: 1765
# Step:  214
# Remaining Nodes: 1755
# Step:  215
# Remaining Nodes: 1745
# Step:  216
# Remaining Nodes: 1735
# Step:  217
# Remaining Nodes: 1725
# Step:  218
# Remaining Nodes: 1715
# Step:  219
# Remaining Nodes: 1704
# Step:  220
# Remaining Nodes: 1694
# Step:  221
# Remaining Nodes: 1684
# Step:  222
# Remaining Nodes: 1674
# Step:  223
# Remaining Nodes: 1663
# Step:  224
# Remaining Nodes: 1653
# Step:  225
# Remaining Nodes: 1643
# Step:  226
# Remaining Nodes: 1632
# Step:  227
# Remaining Nodes: 1622
# Step:  228
# Remaining Nodes: 1612
# Step:  229
# Remaining Nodes: 1602
# Step:  230
# Remaining Nodes: 1592
# Step:  231
# Remaining Nodes: 1582
# Step:  232
# Remaining Nodes: 1572
# Step:  233
# Remaining Nodes: 1558
# Step:  234
# Remaining Nodes: 1542
# Step:  235
# Remaining Nodes: 1532
# Step:  236
# Remaining Nodes: 1522
# Step:  237
# Remaining Nodes: 1512
# Step:  238
# Remaining Nodes: 1502
# Step:  239
# Remaining Nodes: 1492
# Step:  240
# Remaining Nodes: 1482
# Step:  241
# Remaining Nodes: 1472
# Step:  242
# Remaining Nodes: 1462
# Step:  243
# Remaining Nodes: 1452
# Step:  244
# Remaining Nodes: 1440
# Step:  245
# Remaining Nodes: 1430
# Step:  246
# Remaining Nodes: 1420
# Step:  247
# Remaining Nodes: 1409
# Step:  248
# Remaining Nodes: 1399
# Step:  249
# Remaining Nodes: 1389
# Step:  250
# Remaining Nodes: 1379
# Step:  251
# Remaining Nodes: 1369
# Step:  252
# Remaining Nodes: 1358
# Step:  253
# Remaining Nodes: 1347
# Step:  254
# Remaining Nodes: 1177
# Step:  255
# Remaining Nodes: 1082
# Step:  256
# Remaining Nodes: 1072
# Step:  257
# Remaining Nodes: 1062
# Step:  258
# Remaining Nodes: 1051
# Step:  259
# Remaining Nodes: 1038
# Step:  260
# Remaining Nodes: 1028
# Step:  261
# Remaining Nodes: 1018
# Step:  262
# Remaining Nodes: 990
# Step:  263
# Remaining Nodes: 980
# Step:  264
# Remaining Nodes: 731
# Step:  265
# Remaining Nodes: 720
# Step:  266
# Remaining Nodes: 710
# Step:  267
# Remaining Nodes: 700
# Step:  268
# Remaining Nodes: 689
# Step:  269
# Remaining Nodes: 677
# Step:  270
# Remaining Nodes: 667
# Step:  271
# Remaining Nodes: 657
# Step:  272
# Remaining Nodes: 647
# Step:  273
# Remaining Nodes: 625
# Step:  274
# Remaining Nodes: 615
# Step:  275
# Remaining Nodes: 605
# Step:  276
# Remaining Nodes: 595
# Step:  277
# Remaining Nodes: 584
# Step:  278
# Remaining Nodes: 572
# Step:  279
# Remaining Nodes: 562
# Step:  280
# Remaining Nodes: 551
# Step:  281
# Remaining Nodes: 541
# Step:  282
# Remaining Nodes: 528
# Step:  283
# Remaining Nodes: 514
# Step:  284
# Remaining Nodes: 504
# Step:  285
# Remaining Nodes: 493
# Step:  286
# Remaining Nodes: 483
# Step:  287
# Remaining Nodes: 470
# Step:  288
# Remaining Nodes: 459
# Step:  289
# Remaining Nodes: 444
# Step:  290
# Remaining Nodes: 434
# Step:  291
# Remaining Nodes: 416
# Step:  292
# Remaining Nodes: 404
# Step:  293
# Remaining Nodes: 333
# Step:  294
# Remaining Nodes: 287
# Step:  295
# Remaining Nodes: 277
# Step:  296
# Remaining Nodes: 258
# Step:  297
# Remaining Nodes: 247
# Step:  298
# Remaining Nodes: 226
# Step:  299
# Remaining Nodes: 215
# Step:  300
# Remaining Nodes: 203
# Step:  301
# Remaining Nodes: 193
# Step:  302
# Remaining Nodes: 183
# Step:  303
# Remaining Nodes: 172
# Step:  304
# Remaining Nodes: 161
# Step:  305
# Remaining Nodes: 149
# Step:  306
# Remaining Nodes: 138
# Step:  307
# Remaining Nodes: 124
# Step:  308
# Remaining Nodes: 114
# Step:  309
# Remaining Nodes: 54
# Step:  310
# Remaining Nodes: 43
# Step:  311
# Remaining Nodes: 15
# Step:  312
# Remaining Nodes: 2
#
#
# Pagerank Attack:
#
#
# Step:  0
# Remaining Nodes: 3732
# Step:  1
# Remaining Nodes: 3652
# Step:  2
# Remaining Nodes: 3641
# Step:  3
# Remaining Nodes: 3629
# Step:  4
# Remaining Nodes: 3615
# Step:  5
# Remaining Nodes: 3605
# Step:  6
# Remaining Nodes: 3595
# Step:  7
# Remaining Nodes: 3579
# Step:  8
# Remaining Nodes: 3559
# Step:  9
# Remaining Nodes: 3548
# Step:  10
# Remaining Nodes: 3464
# Step:  11
# Remaining Nodes: 3450
# Step:  12
# Remaining Nodes: 3440
# Step:  13
# Remaining Nodes: 3430
# Step:  14
# Remaining Nodes: 3418
# Step:  15
# Remaining Nodes: 3408
# Step:  16
# Remaining Nodes: 3386
# Step:  17
# Remaining Nodes: 3375
# Step:  18
# Remaining Nodes: 3362
# Step:  19
# Remaining Nodes: 3352
# Step:  20
# Remaining Nodes: 3342
# Step:  21
# Remaining Nodes: 3331
# Step:  22
# Remaining Nodes: 2840
# Step:  23
# Remaining Nodes: 2830
# Step:  24
# Remaining Nodes: 2820
# Step:  25
# Remaining Nodes: 2810
# Step:  26
# Remaining Nodes: 2800
# Step:  27
# Remaining Nodes: 2790
# Step:  28
# Remaining Nodes: 2780
# Step:  29
# Remaining Nodes: 2770
# Step:  30
# Remaining Nodes: 2759
# Step:  31
# Remaining Nodes: 2742
# Step:  32
# Remaining Nodes: 2731
# Step:  33
# Remaining Nodes: 2720
# Step:  34
# Remaining Nodes: 2710
# Step:  35
# Remaining Nodes: 2698
# Step:  36
# Remaining Nodes: 2685
# Step:  37
# Remaining Nodes: 2674
# Step:  38
# Remaining Nodes: 2663
# Step:  39
# Remaining Nodes: 2651
# Step:  40
# Remaining Nodes: 2641
# Step:  41
# Remaining Nodes: 2628
# Step:  42
# Remaining Nodes: 2618
# Step:  43
# Remaining Nodes: 2608
# Step:  44
# Remaining Nodes: 2598
# Step:  45
# Remaining Nodes: 2588
# Step:  46
# Remaining Nodes: 2577
# Step:  47
# Remaining Nodes: 2566
# Step:  48
# Remaining Nodes: 2554
# Step:  49
# Remaining Nodes: 2544
# Step:  50
# Remaining Nodes: 2534
# Step:  51
# Remaining Nodes: 2523
# Step:  52
# Remaining Nodes: 2513
# Step:  53
# Remaining Nodes: 2503
# Step:  54
# Remaining Nodes: 2493
# Step:  55
# Remaining Nodes: 2480
# Step:  56
# Remaining Nodes: 2470
# Step:  57
# Remaining Nodes: 2460
# Step:  58
# Remaining Nodes: 2449
# Step:  59
# Remaining Nodes: 2439
# Step:  60
# Remaining Nodes: 2428
# Step:  61
# Remaining Nodes: 2418
# Step:  62
# Remaining Nodes: 2407
# Step:  63
# Remaining Nodes: 2397
# Step:  64
# Remaining Nodes: 2387
# Step:  65
# Remaining Nodes: 2377
# Step:  66
# Remaining Nodes: 1708
# Step:  67
# Remaining Nodes: 1695
# Step:  68
# Remaining Nodes: 1682
# Step:  69
# Remaining Nodes: 1672
# Step:  70
# Remaining Nodes: 1660
# Step:  71
# Remaining Nodes: 1650
# Step:  72
# Remaining Nodes: 1640
# Step:  73
# Remaining Nodes: 1630
# Step:  74
# Remaining Nodes: 1620
# Step:  75
# Remaining Nodes: 1609
# Step:  76
# Remaining Nodes: 1459
# Step:  77
# Remaining Nodes: 1437
# Step:  78
# Remaining Nodes: 1423
# Step:  79
# Remaining Nodes: 1413
# Step:  80
# Remaining Nodes: 1400
# Step:  81
# Remaining Nodes: 1388
# Step:  82
# Remaining Nodes: 1378
# Step:  83
# Remaining Nodes: 1368
# Step:  84
# Remaining Nodes: 1358
# Step:  85
# Remaining Nodes: 1348
# Step:  86
# Remaining Nodes: 1337
# Step:  87
# Remaining Nodes: 1327
# Step:  88
# Remaining Nodes: 1316
# Step:  89
# Remaining Nodes: 1306
# Step:  90
# Remaining Nodes: 1293
# Step:  91
# Remaining Nodes: 1283
# Step:  92
# Remaining Nodes: 1269
# Step:  93
# Remaining Nodes: 1255
# Step:  94
# Remaining Nodes: 1242
# Step:  95
# Remaining Nodes: 1226
# Step:  96
# Remaining Nodes: 1215
# Step:  97
# Remaining Nodes: 1144
# Step:  98
# Remaining Nodes: 1134
# Step:  99
# Remaining Nodes: 1124
# Step:  100
# Remaining Nodes: 1113
# Step:  101
# Remaining Nodes: 1102
# Step:  102
# Remaining Nodes: 1092
# Step:  103
# Remaining Nodes: 1079
# Step:  104
# Remaining Nodes: 1066
# Step:  105
# Remaining Nodes: 1054
# Step:  106
# Remaining Nodes: 1042
# Step:  107
# Remaining Nodes: 1025
# Step:  108
# Remaining Nodes: 1015
# Step:  109
# Remaining Nodes: 1002
# Step:  110
# Remaining Nodes: 992
# Step:  111
# Remaining Nodes: 976
# Step:  112
# Remaining Nodes: 961
# Step:  113
# Remaining Nodes: 944
# Step:  114
# Remaining Nodes: 479
# Step:  115
# Remaining Nodes: 467
# Step:  116
# Remaining Nodes: 389
# Step:  117
# Remaining Nodes: 372
# Step:  118
# Remaining Nodes: 330
# Step:  119
# Remaining Nodes: 305
# Step:  120
# Remaining Nodes: 235
# Step:  121
# Remaining Nodes: 194
# Step:  122
# Remaining Nodes: 104
# Step:  123
# Remaining Nodes: 59
# Step:  124
# Remaining Nodes: 39
# Step:  125
# Remaining Nodes: 26
# Step:  126
# Remaining Nodes: 7
